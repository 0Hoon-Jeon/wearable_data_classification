# %%
import os
import glob
import shutil
import numpy as np 
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score,confusion_matrix
from scipy import signal
import random 
from tensorflow import keras 
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder
import tensorflow as tf
from tensorflow.keras.utils import multi_gpu_model
from tensorflow.keras.layers import Reshape,CuDNNLSTM,LeakyReLU,ZeroPadding1D,Conv1D,BatchNormalization,Activation,MaxPooling1D,Dropout,Dense,Flatten,Bidirectional,LSTM,GlobalAvgPool1D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint,LearningRateScheduler,EarlyStopping,ReduceLROnPlateau
import itertools

from model import *

# %%
prep_path = '/home/ubuntu/Dataset/prep_path_pulse1/'
label_csv = '/home/ubuntu/Dataset/현황_간소화.xlsx'
model_path = '/home/ubuntu/Dataset/model/'
seed = 7

total_len = 194

def load_label():
    label_filename = label_csv
    label_df = pd.read_excel(label_filename,header=2).drop([0]) # remove first line(figure)
    label_df = label_df[['실험NO.','중증도\n5단계']]
    label_df.columns=['subjectnb','label']
    label_df.replace({'label':{'Normal':0,'Presymptomatic AD':0,'Prodroaml AD':1,'AD Dementia 초기 ':3,'AD Dementia 초기':3,'AD Dementia 중기 ':4,'AD Dementia중기 ':4,'MCI unlikely due to AD':5,'PET or CSF (x)':6}},inplace=True)
    label_df.set_index(['subjectnb'],inplace=True)
    
    return dict(label_df.label)


label_dict = load_label()

class Subject():
    def __init__(self,snum,label_dict):
        if type(snum) is int:
            self.snum = 'S{:03}'.format(snum)
        elif type(snum) is str:
            self.snum = snum
        self.path = prep_path+self.snum
        self.data_dict = dict()
        
        for i in range(1,5):
            self.data_dict['E{}'.format(i)] = os.listdir(self.path+'/E{}'.format(i))
            self.data_dict['E{}'.format(i)].sort()
        
        self.severity = label_dict[self.snum]
    def load_data(self,filename):
        data = np.load(filename)
        return data
    
    def get_snum(self):
        return self.snum
    def get_severity(self):
        return self.severity
    
    def get_filenames(self,enum):
        return self.data_dict['E{}'.format(enum)]
    
    def get_filenames_path(self,enum):
        res = []
        file_path = self.path+'/E{}'.format(enum)
        for filename in self.data_dict['E{}'.format(enum)] :
            res.append(file_path+'/'+filename)
        return res
    
    def get_data(self,enum):
        res = []
        filenames = self.get_filenames_path(enum)
        
        for filename in filenames:
            res.append(self.load_data(filename))
        
        return res
    
    def get_len(self):
        res = []
        for i in self.data_dict:
            res.append(len(self.data_dict[i]))
        
        return res
    
    def print_info(self):
        print('{} = severity : {}, '.format(self.snum,self.severity),end='')
        for i,num in enumerate(self.get_len()):
            print('E{} len: {} '.format(i+1,num),end = ',\t')
        print()

S_cnt =  [[] for x in range(7) ]

E_cnt = np.zeros(4,dtype=int)

for i in range(1,total_len+1):
    tmp = Subject(i,label_dict)
    tmp.print_info()
    S_cnt[tmp.get_severity()].append(tmp.get_snum()) 
    E_cnt += tmp.get_len()
    
    
    
    
    
print()
print('S total : ',)
for i,s in enumerate(S_cnt):
    print('E{} : {} '.format(i+1,len(s)),end = ',\t')
print()   
print('E total : ')
for i,e in enumerate(E_cnt):
    print('E{} : {} '.format(i+1,e),end = ',\t')

def subject_split(S_cnt,using_num=[0,1],seed = random.randint(1,100),print_list=False):
    train,val,test = [],[],[]
    
    for i in using_num:
        train_list,remain_list = train_test_split(S_cnt[i],test_size=0.3, random_state=seed)
        val_list,test_list = train_test_split(remain_list,test_size=0.7, random_state=seed)
        print('label {} split result = train : {} , val : {} , test : {} : '.format(i,len(train_list),len(val_list),len(test_list)))
        train.extend(train_list)
        val.extend(val_list)
        test.extend(test_list)
    
    train.sort()
    val.sort()
    test.sort()
    print('total split result = train : {} , val : {} , test : {}'.format(len(train),len(val),len(test)))
    
    if print_list:
        print('\ntrain_list\n', train)
        print('\nval_list\n', val)
        print('\ntest_list\n', test)
        
    return train,val,test





def preprocessing(train_list,val_list,test_list,e_num=1,is_scale=False,resampling_len = 32*32):
    X_train,y_train = [],[]
    X_val,y_val = [],[]
    X_test,y_test = [],[]
    
    
    label_dict = load_label()
    
    print('train_list data load')
    for i in train_list:
#         print(i)
        
        tmp = Subject(i,label_dict)
        label = tmp.get_severity()
        data = tmp.get_data(e_num)
        
        for j in data:
            tmp_x = np.zeros((32,32, 63)).astype(np.float32)
            for k in range(63):
                resample = signal.resample(j[:,k],resampling_len)
                
                if is_scale:
                    
                    scaler = MinMaxScaler(feature_range=(-1,1))
                    resample = scaler.fit_transform(resample.reshape(-1,1))
                
                tmp_x[:,:,k] = np.reshape(resample,(32,32))
                
            
            
#             plt.figure(figsize=(15,15))
#             for k in range(63):
#                 plt.subplot(7,9,k+1)
#                 plt.plot(tmp_x[:,k])
#             return
            X_train.append(tmp_x)
            y_train.append(label)
        
    print('val_list data load')
    print(val_list)
    for i in val_list:
#         print(i)
        
        tmp = Subject(i,label_dict)
        label = tmp.get_severity()
        data = tmp.get_data(e_num)
        for j in data:
            tmp_x = np.zeros((32,32, 63)).astype(np.float32)
            for k in range(63):
#                 tmp_x[:,k] = signal.resample(j[:,k],resampling_len)
                resample = signal.resample(j[:,k],resampling_len)
    
                if is_scale:
                    
                    scaler = MinMaxScaler(feature_range=(-1,1))
                    resample = scaler.fit_transform(resample.reshape(-1,1))
    
                tmp_x[:,:,k] = np.reshape(resample,(32,32))
                
            
                
                
            
            X_val.append(tmp_x)
            y_val.append(label)
            
    print('test_list data load')
    print(test_list)

    for i in test_list:
#         print(i)
        
        tmp = Subject(i,label_dict)
        label = tmp.get_severity()
        data = tmp.get_data(e_num)
        for j in data:
            tmp_x = np.zeros((32,32, 63)).astype(np.float32)
            for k in range(63):
                resample = signal.resample(j[:,k],resampling_len)
                plt.plot(resample)
                return
                if is_scale:
                    
                    scaler = MinMaxScaler(feature_range=(-1,1))
                    resample = scaler.fit_transform(resample.reshape(-1,1))
                
                tmp_x[:,:,k] = np.reshape(resample,(32,32))
#                 tmp_x[:,k] = signal.resample(j[:,k],resampling_len)
                
#             plt.figure(figsize=(15,15))
#             for k in range(63):
#                 plt.subplot(7,9,k+1)
#                 plt.plot(tmp_x[:,k])
#             return
            X_test.append(tmp_x)
            y_test.append(label)
            
            
    enc = OneHotEncoder()
    
    X_train = np.array(X_train)
    
    y_train = np.reshape(y_train,(-1,1))
    y_train = enc.fit_transform(y_train).toarray()
    
    X_val = np.array(X_val)
    
    y_val = np.reshape(y_val,(-1,1))
    y_val = enc.fit_transform(y_val).toarray()
    
    X_test = np.array(X_test)
    
    y_test = np.reshape(y_test,(-1,1))
    y_test = enc.fit_transform(y_test).toarray()
    
    return X_train,y_train,X_val,y_val,X_test,y_test
# Out:
# S001 = severity : 0, E1 len: 4 ,	E2 len: 4 ,	E3 len: 8 ,	E4 len: 5 ,
# S002 = severity : 0, E1 len: 2 ,	E2 len: 4 ,	E3 len: 8 ,	E4 len: 0 ,
# S003 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 0 ,
# S004 = severity : 0, E1 len: 2 ,	E2 len: 4 ,	E3 len: 14 ,	E4 len: 0 ,
# S005 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 9 ,	E4 len: 6 ,
# S006 = severity : 3, E1 len: 4 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 6 ,
# S007 = severity : 1, E1 len: 2 ,	E2 len: 6 ,	E3 len: 6 ,	E4 len: 11 ,
# S008 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 4 ,
# S009 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 7 ,	E4 len: 5 ,
# S010 = severity : 0, E1 len: 3 ,	E2 len: 3 ,	E3 len: 6 ,	E4 len: 6 ,
# S011 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 4 ,
# S012 = severity : 5, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 5 ,
# S013 = severity : 5, E1 len: 2 ,	E2 len: 2 ,	E3 len: 8 ,	E4 len: 5 ,
# S014 = severity : 5, E1 len: 4 ,	E2 len: 4 ,	E3 len: 15 ,	E4 len: 11 ,
# S015 = severity : 4, E1 len: 5 ,	E2 len: 2 ,	E3 len: 0 ,	E4 len: 0 ,
# S016 = severity : 3, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 4 ,
# S017 = severity : 0, E1 len: 3 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S018 = severity : 0, E1 len: 3 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S019 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S020 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S021 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S022 = severity : 3, E1 len: 4 ,	E2 len: 2 ,	E3 len: 9 ,	E4 len: 3 ,
# S023 = severity : 1, E1 len: 4 ,	E2 len: 2 ,	E3 len: 12 ,	E4 len: 9 ,
# S024 = severity : 0, E1 len: 4 ,	E2 len: 4 ,	E3 len: 10 ,	E4 len: 10 ,
# S025 = severity : 5, E1 len: 5 ,	E2 len: 4 ,	E3 len: 11 ,	E4 len: 7 ,
# S026 = severity : 0, E1 len: 3 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 4 ,
# S027 = severity : 0, E1 len: 3 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S028 = severity : 0, E1 len: 4 ,	E2 len: 5 ,	E3 len: 13 ,	E4 len: 8 ,
# S029 = severity : 1, E1 len: 4 ,	E2 len: 5 ,	E3 len: 12 ,	E4 len: 7 ,
# S030 = severity : 0, E1 len: 5 ,	E2 len: 4 ,	E3 len: 10 ,	E4 len: 8 ,
# S031 = severity : 0, E1 len: 4 ,	E2 len: 4 ,	E3 len: 12 ,	E4 len: 6 ,
# S032 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S033 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S034 = severity : 1, E1 len: 7 ,	E2 len: 4 ,	E3 len: 14 ,	E4 len: 8 ,
# S035 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 12 ,	E4 len: 6 ,
# S036 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S037 = severity : 1, E1 len: 5 ,	E2 len: 4 ,	E3 len: 13 ,	E4 len: 8 ,
# S038 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 5 ,
# S039 = severity : 0, E1 len: 4 ,	E2 len: 13 ,	E3 len: 6 ,	E4 len: 11 ,
# S040 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 12 ,	E4 len: 7 ,
# S041 = severity : 1, E1 len: 2 ,	E2 len: 6 ,	E3 len: 13 ,	E4 len: 7 ,
# S042 = severity : 1, E1 len: 4 ,	E2 len: 5 ,	E3 len: 13 ,	E4 len: 9 ,
# S043 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 12 ,	E4 len: 7 ,
# S044 = severity : 3, E1 len: 2 ,	E2 len: 4 ,	E3 len: 8 ,	E4 len: 2 ,
# S045 = severity : 1, E1 len: 4 ,	E2 len: 5 ,	E3 len: 9 ,	E4 len: 7 ,
# S046 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 10 ,	E4 len: 7 ,
# S047 = severity : 0, E1 len: 4 ,	E2 len: 4 ,	E3 len: 14 ,	E4 len: 8 ,
# S048 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S049 = severity : 0, E1 len: 4 ,	E2 len: 5 ,	E3 len: 10 ,	E4 len: 9 ,
# S050 = severity : 0, E1 len: 4 ,	E2 len: 0 ,	E3 len: 7 ,	E4 len: 3 ,
# S051 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 4 ,
# S052 = severity : 3, E1 len: 4 ,	E2 len: 6 ,	E3 len: 9 ,	E4 len: 8 ,
# S053 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S054 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S055 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S056 = severity : 0, E1 len: 2 ,	E2 len: 3 ,	E3 len: 6 ,	E4 len: 5 ,
# S057 = severity : 0, E1 len: 4 ,	E2 len: 4 ,	E3 len: 13 ,	E4 len: 5 ,
# S058 = severity : 0, E1 len: 6 ,	E2 len: 4 ,	E3 len: 11 ,	E4 len: 6 ,
# S059 = severity : 0, E1 len: 4 ,	E2 len: 4 ,	E3 len: 10 ,	E4 len: 6 ,
# S060 = severity : 1, E1 len: 7 ,	E2 len: 5 ,	E3 len: 12 ,	E4 len: 6 ,
# S061 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S062 = severity : 0, E1 len: 3 ,	E2 len: 4 ,	E3 len: 11 ,	E4 len: 6 ,
# S063 = severity : 1, E1 len: 6 ,	E2 len: 4 ,	E3 len: 15 ,	E4 len: 6 ,
# S064 = severity : 1, E1 len: 4 ,	E2 len: 5 ,	E3 len: 10 ,	E4 len: 8 ,
# S065 = severity : 1, E1 len: 3 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S066 = severity : 3, E1 len: 10 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 4 ,
# S067 = severity : 3, E1 len: 2 ,	E2 len: 1 ,	E3 len: 5 ,	E4 len: 3 ,
# S068 = severity : 1, E1 len: 9 ,	E2 len: 0 ,	E3 len: 0 ,	E4 len: 4 ,
# S069 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S070 = severity : 0, E1 len: 5 ,	E2 len: 4 ,	E3 len: 11 ,	E4 len: 7 ,
# S071 = severity : 6, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S072 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 5 ,
# S073 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 4 ,
# S074 = severity : 6, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S075 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 11 ,	E4 len: 8 ,
# S076 = severity : 0, E1 len: 4 ,	E2 len: 4 ,	E3 len: 12 ,	E4 len: 7 ,
# S077 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 16 ,	E4 len: 6 ,
# S078 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 14 ,	E4 len: 9 ,
# S079 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 13 ,	E4 len: 6 ,
# S080 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 10 ,	E4 len: 6 ,
# S081 = severity : 0, E1 len: 4 ,	E2 len: 4 ,	E3 len: 10 ,	E4 len: 6 ,
# S082 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 10 ,	E4 len: 7 ,
# S083 = severity : 0, E1 len: 2 ,	E2 len: 3 ,	E3 len: 5 ,	E4 len: 3 ,
# S084 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S085 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S086 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S087 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S088 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S089 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 4 ,
# S090 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S091 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S092 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 7 ,	E4 len: 3 ,
# S093 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S094 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 7 ,	E4 len: 3 ,
# S095 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S096 = severity : 0, E1 len: 3 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S097 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S098 = severity : 1, E1 len: 4 ,	E2 len: 5 ,	E3 len: 17 ,	E4 len: 11 ,
# S099 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 8 ,
# S100 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 5 ,
# S101 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 6 ,
# S102 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S103 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S104 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 4 ,
# S105 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 7 ,	E4 len: 4 ,
# S106 = severity : 3, E1 len: 3 ,	E2 len: 8 ,	E3 len: 8 ,	E4 len: 5 ,
# S107 = severity : 3, E1 len: 3 ,	E2 len: 4 ,	E3 len: 14 ,	E4 len: 12 ,
# S108 = severity : 0, E1 len: 3 ,	E2 len: 2 ,	E3 len: 8 ,	E4 len: 6 ,
# S109 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 5 ,
# S110 = severity : 0, E1 len: 4 ,	E2 len: 3 ,	E3 len: 9 ,	E4 len: 3 ,
# S111 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S112 = severity : 1, E1 len: 2 ,	E2 len: 3 ,	E3 len: 9 ,	E4 len: 3 ,
# S113 = severity : 0, E1 len: 4 ,	E2 len: 4 ,	E3 len: 10 ,	E4 len: 6 ,
# S114 = severity : 1, E1 len: 4 ,	E2 len: 5 ,	E3 len: 12 ,	E4 len: 9 ,
# S115 = severity : 1, E1 len: 3 ,	E2 len: 3 ,	E3 len: 8 ,	E4 len: 5 ,
# S116 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 7 ,	E4 len: 3 ,
# S117 = severity : 1, E1 len: 4 ,	E2 len: 6 ,	E3 len: 13 ,	E4 len: 10 ,
# S118 = severity : 0, E1 len: 4 ,	E2 len: 4 ,	E3 len: 10 ,	E4 len: 7 ,
# S119 = severity : 0, E1 len: 3 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S120 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S121 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S122 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S123 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S124 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 7 ,	E4 len: 3 ,
# S125 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 7 ,	E4 len: 3 ,
# S126 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 4 ,
# S127 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S128 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S129 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 7 ,
# S130 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 8 ,	E4 len: 4 ,
# S131 = severity : 0, E1 len: 2 ,	E2 len: 4 ,	E3 len: 5 ,	E4 len: 3 ,
# S132 = severity : 0, E1 len: 4 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 4 ,
# S133 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 11 ,	E4 len: 12 ,
# S134 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 7 ,	E4 len: 4 ,
# S135 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 4 ,
# S136 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 10 ,	E4 len: 7 ,
# S137 = severity : 1, E1 len: 4 ,	E2 len: 4 ,	E3 len: 11 ,	E4 len: 7 ,
# S138 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S139 = severity : 1, E1 len: 3 ,	E2 len: 2 ,	E3 len: 7 ,	E4 len: 3 ,
# S140 = severity : 1, E1 len: 4 ,	E2 len: 8 ,	E3 len: 22 ,	E4 len: 10 ,
# S141 = severity : 1, E1 len: 2 ,	E2 len: 6 ,	E3 len: 12 ,	E4 len: 7 ,
# S142 = severity : 3, E1 len: 3 ,	E2 len: 5 ,	E3 len: 13 ,	E4 len: 8 ,
# S143 = severity : 1, E1 len: 2 ,	E2 len: 3 ,	E3 len: 7 ,	E4 len: 3 ,
# S144 = severity : 1, E1 len: 3 ,	E2 len: 2 ,	E3 len: 10 ,	E4 len: 4 ,
# S145 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 7 ,	E4 len: 4 ,
# S146 = severity : 1, E1 len: 5 ,	E2 len: 5 ,	E3 len: 10 ,	E4 len: 7 ,
# S147 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S148 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S149 = severity : 1, E1 len: 2 ,	E2 len: 5 ,	E3 len: 8 ,	E4 len: 5 ,
# S150 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S151 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S152 = severity : 0, E1 len: 4 ,	E2 len: 4 ,	E3 len: 10 ,	E4 len: 6 ,
# S153 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S154 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 4 ,
# S155 = severity : 0, E1 len: 2 ,	E2 len: 3 ,	E3 len: 5 ,	E4 len: 3 ,
# S156 = severity : 3, E1 len: 1 ,	E2 len: 4 ,	E3 len: 2 ,	E4 len: 2 ,
# S157 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 8 ,	E4 len: 3 ,
# S158 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 6 ,	E4 len: 3 ,
# S159 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 9 ,	E4 len: 3 ,
# S160 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S161 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S162 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S163 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S164 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 7 ,	E4 len: 3 ,
# S165 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S166 = severity : 3, E1 len: 1 ,	E2 len: 4 ,	E3 len: 0 ,	E4 len: 1 ,
# S167 = severity : 0, E1 len: 2 ,	E2 len: 1 ,	E3 len: 5 ,	E4 len: 3 ,
# S168 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 4 ,
# S169 = severity : 3, E1 len: 1 ,	E2 len: 1 ,	E3 len: 2 ,	E4 len: 1 ,
# S170 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S171 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S172 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S173 = severity : 1, E1 len: 2 ,	E2 len: 3 ,	E3 len: 5 ,	E4 len: 4 ,
# S174 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S175 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S176 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S177 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S178 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S179 = severity : 3, E1 len: 2 ,	E2 len: 0 ,	E3 len: 2 ,	E4 len: 1 ,
# S180 = severity : 3, E1 len: 1 ,	E2 len: 2 ,	E3 len: 1 ,	E4 len: 1 ,
# S181 = severity : 4, E1 len: 1 ,	E2 len: 1 ,	E3 len: 2 ,	E4 len: 1 ,
# S182 = severity : 3, E1 len: 1 ,	E2 len: 3 ,	E3 len: 1 ,	E4 len: 1 ,
# S183 = severity : 0, E1 len: 2 ,	E2 len: 3 ,	E3 len: 5 ,	E4 len: 3 ,
# S184 = severity : 0, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S185 = severity : 4, E1 len: 0 ,	E2 len: 0 ,	E3 len: 0 ,	E4 len: 0 ,
# S186 = severity : 3, E1 len: 1 ,	E2 len: 2 ,	E3 len: 1 ,	E4 len: 1 ,
# S187 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S188 = severity : 3, E1 len: 1 ,	E2 len: 2 ,	E3 len: 1 ,	E4 len: 1 ,
# S189 = severity : 3, E1 len: 2 ,	E2 len: 2 ,	E3 len: 2 ,	E4 len: 1 ,
# S190 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 8 ,	E4 len: 3 ,
# S191 = severity : 0, E1 len: 2 ,	E2 len: 3 ,	E3 len: 5 ,	E4 len: 3 ,
# S192 = severity : 1, E1 len: 2 ,	E2 len: 2 ,	E3 len: 5 ,	E4 len: 3 ,
# S193 = severity : 3, E1 len: 1 ,	E2 len: 1 ,	E3 len: 3 ,	E4 len: 1 ,
# S194 = severity : 3, E1 len: 1 ,	E2 len: 1 ,	E3 len: 1 ,	E4 len: 1 ,
#
# S total :
# E1 : 95 ,	E2 : 69 ,	E3 : 0 ,	E4 : 21 ,	E5 : 3 ,	E6 : 4 ,	E7 : 2 ,
# E total :
# E1 : 529 ,	E2 : 545 ,	E3 : 1390 ,	E4 : 859 ,

# %%
train_list,val_list,test_list = subject_split(S_cnt = S_cnt,using_num=[0,1] ,seed = 7,print_list=True)
X_train,y_train,X_val,y_val,X_test,y_test = preprocessing(train_list,val_list,test_list,is_scale=True,e_num=3)
# Out:
# label 0 split result = train : 66 , val : 8 , test : 21 :
# label 1 split result = train : 48 , val : 6 , test : 15 :
# total split result = train : 114 , val : 14 , test : 36
#
# train_list
#  ['S001', 'S002', 'S004', 'S005', 'S007', 'S009', 'S010', 'S011', 'S017', 'S018', 'S023', 'S024', 'S027', 'S031', 'S032', 'S033', 'S034', 'S035', 'S037', 'S038', 'S039', 'S040', 'S041', 'S042', 'S043', 'S046', 'S048', 'S049', 'S050', 'S053', 'S054', 'S055', 'S057', 'S058', 'S061', 'S062', 'S065', 'S069', 'S075', 'S076', 'S077', 'S078', 'S079', 'S080', 'S081', 'S085', 'S086', 'S087', 'S088', 'S089', 'S090', 'S091', 'S092', 'S093', 'S096', 'S097', 'S099', 'S100', 'S101', 'S102', 'S105', 'S108', 'S110', 'S112', 'S116', 'S117', 'S118', 'S120', 'S121', 'S122', 'S123', 'S125', 'S126', 'S128', 'S129', 'S130', 'S131', 'S132', 'S133', 'S134', 'S135', 'S136', 'S137', 'S139', 'S140', 'S141', 'S143', 'S145', 'S146', 'S147', 'S148', 'S150', 'S151', 'S153', 'S155', 'S157', 'S158', 'S159', 'S160', 'S162', 'S164', 'S167', 'S170', 'S172', 'S173', 'S174', 'S175', 'S176', 'S177', 'S184', 'S187', 'S190', 'S191', 'S192']
#
# val_list
#  ['S070', 'S072', 'S082', 'S083', 'S084', 'S103', 'S104', 'S111', 'S119', 'S144', 'S152', 'S161', 'S163', 'S183']
#
# test_list
#  ['S003', 'S008', 'S019', 'S020', 'S021', 'S026', 'S028', 'S029', 'S030', 'S036', 'S045', 'S047', 'S051', 'S056', 'S059', 'S060', 'S063', 'S064', 'S068', 'S073', 'S094', 'S095', 'S098', 'S109', 'S113', 'S114', 'S115', 'S124', 'S127', 'S138', 'S149', 'S154', 'S165', 'S168', 'S171', 'S178']
# train_list data load
# val_list data load
# ['S070', 'S072', 'S082', 'S083', 'S084', 'S103', 'S104', 'S111', 'S119', 'S144', 'S152', 'S161', 'S163', 'S183']
# test_list data load
# ['S003', 'S008', 'S019', 'S020', 'S021', 'S026', 'S028', 'S029', 'S030', 'S036', 'S045', 'S047', 'S051', 'S056', 'S059', 'S060', 'S063', 'S064', 'S068', 'S073', 'S094', 'S095', 'S098', 'S109', 'S113', 'S114', 'S115', 'S124', 'S127', 'S138', 'S149', 'S154', 'S165', 'S168', 'S171', 'S178']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-b6d04078b286> in <module>
#       1 train_list,val_list,test_list = subject_split(S_cnt = S_cnt,using_num=[0,1] ,seed = 7,print_list=True)
# ----> 2 X_train,y_train,X_val,y_val,X_test,y_test = preprocessing(train_list,val_list,test_list,is_scale=True,e_num=3)
#
# TypeError: 'NoneType' object is not iterable

# %%
def get_model1(input_shape,nb_classes):
    n_feature_maps = 64

    input_layer = keras.layers.Input(input_shape)

    # BLOCK 1

    conv_x = keras.layers.Conv1D(filters=n_feature_maps, kernel_size=8, padding='same')(input_layer)
    conv_x = keras.layers.BatchNormalization()(conv_x)
    conv_x = keras.layers.Activation('relu')(conv_x)

    conv_y = keras.layers.Conv1D(filters=n_feature_maps, kernel_size=5, padding='same')(conv_x)
    conv_y = keras.layers.BatchNormalization()(conv_y)
    conv_y = keras.layers.Activation('relu')(conv_y)

    conv_z = keras.layers.Conv1D(filters=n_feature_maps, kernel_size=3, padding='same')(conv_y)
    conv_z = keras.layers.BatchNormalization()(conv_z)

    # expand channels for the sum
    shortcut_y = keras.layers.Conv1D(filters=n_feature_maps, kernel_size=1, padding='same')(input_layer)
    shortcut_y = keras.layers.BatchNormalization()(shortcut_y)

    output_block_1 = keras.layers.add([shortcut_y, conv_z])
    output_block_1 = keras.layers.Activation('relu')(output_block_1)

    # BLOCK 2

    conv_x = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=8, padding='same')(output_block_1)
    conv_x = keras.layers.BatchNormalization()(conv_x)
    conv_x = keras.layers.Activation('relu')(conv_x)

    conv_y = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=5, padding='same')(conv_x)
    conv_y = keras.layers.BatchNormalization()(conv_y)
    conv_y = keras.layers.Activation('relu')(conv_y)

    conv_z = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=3, padding='same')(conv_y)
    conv_z = keras.layers.BatchNormalization()(conv_z)

    # expand channels for the sum
    shortcut_y = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=1, padding='same')(output_block_1)
    shortcut_y = keras.layers.BatchNormalization()(shortcut_y)

    output_block_2 = keras.layers.add([shortcut_y, conv_z])
    output_block_2 = keras.layers.Activation('relu')(output_block_2)

    # BLOCK 3

    conv_x = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=8, padding='same')(output_block_2)
    conv_x = keras.layers.BatchNormalization()(conv_x)
    conv_x = keras.layers.Activation('relu')(conv_x)

    conv_y = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=5, padding='same')(conv_x)
    conv_y = keras.layers.BatchNormalization()(conv_y)
    conv_y = keras.layers.Activation('relu')(conv_y)

    conv_z = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=3, padding='same')(conv_y)
    conv_z = keras.layers.BatchNormalization()(conv_z)

    # no need to expand channels because they are equal
    shortcut_y = keras.layers.BatchNormalization()(output_block_2)

    output_block_3 = keras.layers.add([shortcut_y, conv_z])
    output_block_3 = keras.layers.Activation('relu')(output_block_3)

    # FINAL

    gap_layer = keras.layers.GlobalAveragePooling1D()(output_block_3)

    output_layer = keras.layers.Dense(nb_classes, activation='softmax')(gap_layer)

    model = keras.models.Model(inputs=input_layer, outputs=output_layer)

    
    
    return model

# %%
def get_model2(input_shape,nb_classes):
    n_feature_maps = 128
    input_layer = keras.layers.Input(shape=(input_shape))
    
    conv_x = keras.layers.BatchNormalization()(input_layer)
    conv_x = keras.layers.Conv1D(n_feature_maps, 8, 1, padding='same')(conv_x)
    conv_x = keras.layers.BatchNormalization()(conv_x)
    conv_x = keras.layers.Activation('relu')(conv_x)
     
    print ('build conv_y')
    conv_y = keras.layers.Conv1D(n_feature_maps, 5, 1, padding='same')(conv_x)
    conv_y = keras.layers.BatchNormalization()(conv_y)
    conv_y = keras.layers.Activation('relu')(conv_y)
     
    print ('build conv_z')
    conv_z = keras.layers.Conv1D(n_feature_maps, 3, 1, padding='same')(conv_y)
    conv_z = keras.layers.BatchNormalization()(conv_z)
     
    is_expand_channels = not (input_shape[-1] == n_feature_maps)
    if is_expand_channels:
        shortcut_y = keras.layers.Conv1D(n_feature_maps, 1, 1,padding='same')(input_layer)
        shortcut_y = keras.layers.BatchNormalization()(shortcut_y)
    else:
        shortcut_y = keras.layers.BatchNormalization()(input_layer)
    print ('Merging skip connection')
    y = keras.layers.Add()([shortcut_y, conv_z])
    y = keras.layers.Activation('relu')(y)
     
    print ('build conv_x')
    x1 = y
    conv_x = keras.layers.Conv1D(n_feature_maps*2, 8, 1, padding='same')(x1)
    conv_x = keras.layers.BatchNormalization()(conv_x)
    conv_x = keras.layers.Activation('relu')(conv_x)
     
    print ('build conv_y')
    conv_y = keras.layers.Conv1D(n_feature_maps*2, 5, 1, padding='same')(conv_x)
    conv_y = keras.layers.BatchNormalization()(conv_y)
    conv_y = keras.layers.Activation('relu')(conv_y)
     
    print ('build conv_z')
    conv_z = keras.layers.Conv1D(n_feature_maps*2, 3, 1, padding='same')(conv_y)
    conv_z = keras.layers.BatchNormalization()(conv_z)
     
    is_expand_channels = not (input_shape[-1] == n_feature_maps*2)
    if is_expand_channels:
        shortcut_y = keras.layers.Conv1D(n_feature_maps*2, 1, 1,padding='same')(x1)
        shortcut_y = keras.layers.BatchNormalization()(shortcut_y)
    else:
        shortcut_y = keras.layers.BatchNormalization()(x1)
    print ('Merging skip connection')
    y = keras.layers.Add()([shortcut_y, conv_z])
    y = keras.layers.Activation('relu')(y)
     
    print ('build conv_x')
    x1 = y
    conv_x = keras.layers.Conv1D(n_feature_maps*2, 8, 1, padding='same')(x1)
    conv_x = keras.layers.BatchNormalization()(conv_x)
    conv_x = keras.layers.Activation('relu')(conv_x)
     
    print ('build conv_y')
    conv_y = keras.layers.Conv1D(n_feature_maps*2, 5, 1, padding='same')(conv_x)
    conv_y = keras.layers.BatchNormalization()(conv_y)
    conv_y = keras.layers.Activation('relu')(conv_y)
     
    print ('build conv_z')
    conv_z = keras.layers.Conv1D(n_feature_maps*2, 3, 1, padding='same')(conv_y)
    conv_z = keras.layers.BatchNormalization()(conv_z)

    is_expand_channels = not (input_shape[-1] == n_feature_maps*2)
    if is_expand_channels:
        shortcut_y = keras.layers.Conv1D(n_feature_maps*2, 1, 1,padding='same')(x1)
        shortcut_y = keras.layers.BatchNormalization()(shortcut_y)
    else:
        shortcut_y = keras.layers.BatchNormalization()(x1)
    print ('Merging skip connection')
    y = keras.layers.Add()([shortcut_y, conv_z])
    y = keras.layers.Activation('relu')(y)
     
    full = keras.layers.GlobalAveragePooling1D()(y)
    out = keras.layers.Dense(nb_classes, activation='softmax')(full)
    
    model = keras.models.Model(inputs=input_layer, outputs=out)
    
    return model

# %%
def get_model3(input_shape,nb_classes):

    input_layer = keras.layers.Input(input_shape)
    
    x = LSTM(50,return_sequences=True)(input_layer)
    x = Dropout(0.5)(x)

    x = LSTM(224)(x)
    x = Dropout(0.5)(x)
    
    # FINAL

    output_layer = keras.layers.Dense(nb_classes,activation='softmax')(x)

    model = keras.models.Model(inputs=input_layer, outputs=output_layer)
    
    return model

# %%
def get_model4(input_shape,nb_classes):
    
    
    # RNN Model
    rnn = Sequential()
    rnn.add(CuDNNLSTM(3,input_shape=input_shape, return_sequences=True, kernel_initializer='TruncatedNormal'))
    rnn.add(BatchNormalization())
    rnn.add(LeakyReLU())
    rnn.add(Dropout(0.622))
    
    for _ in range(0):
        rnn.add(CuDNNLSTM(32, kernel_initializer='TruncatedNormal', return_sequences=True))
        rnn.add(BatchNormalization())
        rnn.add(LeakyReLU())
        rnn.add(Dropout(0.612))   
    
    rnn.add(CuDNNLSTM(4, kernel_initializer='TruncatedNormal', return_sequences=False))
    rnn.add(BatchNormalization())
    rnn.add(LeakyReLU())
    rnn.add(Dropout(0.281))
    
    # DNN Model
    
    dnn = rnn
    
    for _ in range(4):
        dnn.add(Dense(128, kernel_initializer='TruncatedNormal'))
        dnn.add(BatchNormalization())
        dnn.add(LeakyReLU())
        dnn.add(Dropout(0.006))
                 
    for _ in range(4):
        dnn.add(Dense(16, kernel_initializer='TruncatedNormal'))
        dnn.add(BatchNormalization())
        dnn.add(LeakyReLU())
        dnn.add(Dropout(0.08))
    
    for _ in range(4):
        dnn.add(Dense(256, kernel_initializer='TruncatedNormal'))
        dnn.add(BatchNormalization())
        dnn.add(LeakyReLU())
        dnn.add(Dropout(0.171))
  
    dnn.add(Dense(512, kernel_initializer='TruncatedNormal'))
    dnn.add(BatchNormalization())
    dnn.add(LeakyReLU())
    dnn.add(Dropout(0.257))
    
    dnn.add(Dense(nb_classes))
    dnn.add(Activation('softmax'))
    
    
    return dnn

# %%
def get_model5(input_shape,nb_classes):
    seq_length = 256
    kernel_size = 3
    activation = "relu"
    padding = "valid"
    inp = keras.layers.Input(shape=(input_shape))
    # CONV1
    x = Conv1D(filters=128,
               kernel_size=kernel_size,
               activation=activation,
               padding=padding)(inp)
    x = MaxPooling1D(2)(x)

    # CONV2
    x = Conv1D(filters=128,
               kernel_size=kernel_size,
               activation=activation,
               padding=padding)(x)
    x = MaxPooling1D(2)(x)

    # CONV3
    x = Conv1D(filters=128,
               kernel_size=kernel_size,
               activation=activation,
               padding=padding)(x)
    x = MaxPooling1D(2)(x)

    # CONV4
    x = Conv1D(filters=128,
               kernel_size=kernel_size,
               activation=activation,
               padding=padding)(x)
    x = MaxPooling1D(2)(x)

    # Residual block
#     inp_res = Fla((12, 64))(inp)
#     x = Concatenate(axis=-1)([x, inp_res])

    # Flatten, FC1, FC2, Softmax
    x = Flatten()(x)
    x = Dense(150, activation=activation)(x)
    x = Dense(100, activation=activation)(x)
    x = Dense(2, activation="softmax")(x)

    return Model(inputs=inp, outputs=x)

# %%
def conv2d(input_shape,nb_classes):
    n_feature_maps = 192

    input_layer = keras.layers.Input(input_shape)

    # BLOCK 1

    conv_x = keras.layers.Conv2D(filters=n_feature_maps, kernel_size=8, padding='same')(input_layer)
    conv_x = keras.layers.BatchNormalization()(conv_x)
    conv_x = keras.layers.Activation('relu')(conv_x)

    conv_y = keras.layers.Conv2D(filters=n_feature_maps, kernel_size=5, padding='same')(conv_x)
    conv_y = keras.layers.BatchNormalization()(conv_y)
    conv_y = keras.layers.Activation('relu')(conv_y)

    conv_z = keras.layers.Conv2D(filters=n_feature_maps, kernel_size=3, padding='same')(conv_y)
    conv_z = keras.layers.BatchNormalization()(conv_z)

    # expand channels for the sum
    shortcut_y = keras.layers.Conv2D(filters=n_feature_maps, kernel_size=1, padding='same')(input_layer)
    shortcut_y = keras.layers.BatchNormalization()(shortcut_y)

    output_block_1 = keras.layers.add([shortcut_y, conv_z])
    output_block_1 = keras.layers.Activation('relu')(output_block_1)

    # BLOCK 2

    conv_x = keras.layers.Conv2D(filters=n_feature_maps * 2, kernel_size=8, padding='same')(output_block_1)
    conv_x = keras.layers.BatchNormalization()(conv_x)
    conv_x = keras.layers.Activation('relu')(conv_x)

    conv_y = keras.layers.Conv2D(filters=n_feature_maps * 2, kernel_size=5, padding='same')(conv_x)
    conv_y = keras.layers.BatchNormalization()(conv_y)
    conv_y = keras.layers.Activation('relu')(conv_y)

    conv_z = keras.layers.Conv2D(filters=n_feature_maps * 2, kernel_size=3, padding='same')(conv_y)
    conv_z = keras.layers.BatchNormalization()(conv_z)

    # expand channels for the sum
    shortcut_y = keras.layers.Conv2D(filters=n_feature_maps * 2, kernel_size=1, padding='same')(output_block_1)
    shortcut_y = keras.layers.BatchNormalization()(shortcut_y)

    output_block_2 = keras.layers.add([shortcut_y, conv_z])
    output_block_2 = keras.layers.Activation('relu')(output_block_2)

    # BLOCK 3

    conv_x = keras.layers.Conv2D(filters=n_feature_maps * 2, kernel_size=8, padding='same')(output_block_2)
    conv_x = keras.layers.BatchNormalization()(conv_x)
    conv_x = keras.layers.Activation('relu')(conv_x)

    conv_y = keras.layers.Conv2D(filters=n_feature_maps * 2, kernel_size=5, padding='same')(conv_x)
    conv_y = keras.layers.BatchNormalization()(conv_y)
    conv_y = keras.layers.Activation('relu')(conv_y)

    conv_z = keras.layers.Conv2D(filters=n_feature_maps * 2, kernel_size=3, padding='same')(conv_y)
    conv_z = keras.layers.BatchNormalization()(conv_z)

    # no need to expand channels because they are equal
    shortcut_y = keras.layers.BatchNormalization()(output_block_2)

    output_block_3 = keras.layers.add([shortcut_y, conv_z])
    output_block_3 = keras.layers.Activation('relu')(output_block_3)

    # FINAL

    gap_layer = keras.layers.GlobalAveragePooling2D()(output_block_3)

    output_layer = keras.layers.Dense(nb_classes, activation='softmax')(gap_layer)

    model = keras.models.Model(inputs=input_layer, outputs=output_layer)

    
    
    return model

# %%
def res3d(inputs, weight_decay):
    # Res3D Block 1
    conv3d_1 = keras.layers.Conv1D(64, 3, strides=(1,2,2), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False,
                    name='Conv1D_1')(inputs)
    conv3d_1 = keras.layers.BatchNormalization(name='BatchNorm_1_0')(conv3d_1)
    conv3d_1 = keras.layers.Activation('relu', name='ReLU_1')(conv3d_1)

    # Res3D Block 2
    conv3d_2a_1 = keras.layers.Conv1D(64, 1, strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_2a_1')(conv3d_1)
    conv3d_2a_1 = keras.layers.BatchNormalization(name='BatchNorm_2a_1')(conv3d_2a_1)
    conv3d_2a_a = keras.layers.Conv1D(64, 3, strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_2a_a')(conv3d_1)
    conv3d_2a_a = keras.layers.BatchNormalization(name='BatchNorm_2a_a')(conv3d_2a_a)
    conv3d_2a_a = keras.layers.Activation('relu', name='ReLU_2a_a')(conv3d_2a_a)
    conv3d_2a_b = keras.layers.Conv1D(64, (3,3,3), strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_2a_b')(conv3d_2a_a)
    conv3d_2a_b = keras.layers.BatchNormalization(name='BatchNorm_2a_b')(conv3d_2a_b)
    conv3d_2a = keras.layers.Add(name='Add_2a')([conv3d_2a_1, conv3d_2a_b])
    conv3d_2a = keras.layers.Activation('relu', name='ReLU_2a')(conv3d_2a)

    conv3d_2b_a = keras.layers.Conv1D(64, (3,3,3), strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_2b_a')(conv3d_2a)
    conv3d_2b_a = keras.layers.BatchNormalization(name='BatchNorm_2b_a')(conv3d_2b_a)
    conv3d_2b_a = keras.layers.Activation('relu', name='ReLU_2b_a')(conv3d_2b_a)
    conv3d_2b_b = keras.layers.Conv1D(64, (3,3,3), strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_2b_b')(conv3d_2b_a)
    conv3d_2b_b = keras.layers.BatchNormalization(name='BatchNorm_2b_b')(conv3d_2b_b)
    conv3d_2b = keras.layers.Add(name='Add_2b')([conv3d_2a, conv3d_2b_b])
    conv3d_2b = keras.layers.Activation('relu', name='ReLU_2b')(conv3d_2b)

    # Res3D Block 3
    conv3d_3a_1 = keras.layers.Conv1D(128, (1,1,1), strides=(2,2,2), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_3a_1')(conv3d_2b)
    conv3d_3a_1 = keras.layers.BatchNormalization(name='BatchNorm_3a_1')(conv3d_3a_1)
    conv3d_3a_a = keras.layers.Conv1D(128, (3,3,3), strides=(2,2,2), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_3a_a')(conv3d_2b)
    conv3d_3a_a = keras.layers.BatchNormalization(name='BatchNorm_3a_a')(conv3d_3a_a)
    conv3d_3a_a = keras.layers.Activation('relu', name='ReLU_3a_a')(conv3d_3a_a)
    conv3d_3a_b = keras.layers.Conv1D(128, (3,3,3), strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_3a_b')(conv3d_3a_a)
    conv3d_3a_b = keras.layers.BatchNormalization(name='BatchNorm_3a_b')(conv3d_3a_b)
    conv3d_3a = keras.layers.Add(name='Add_3a')([conv3d_3a_1, conv3d_3a_b])
    conv3d_3a = keras.layers.Activation('relu', name='ReLU_3a')(conv3d_3a)

    conv3d_3b_a = keras.layers.Conv1D(128, (3,3,3), strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_3b_a')(conv3d_3a)
    conv3d_3b_a = keras.layers.BatchNormalization(name='BatchNorm_3b_a')(conv3d_3b_a)
    conv3d_3b_a = keras.layers.Activation('relu', name='ReLU_3b_a')(conv3d_3b_a)
    conv3d_3b_b = keras.layers.Conv1D(128, (3,3,3), strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_3b_b')(conv3d_3b_a)
    conv3d_3b_b = keras.layers.BatchNormalization(name='BatchNorm_3b_b')(conv3d_3b_b)
    conv3d_3b = keras.layers.Add(name='Add_3b')([conv3d_3a, conv3d_3b_b])
    conv3d_3b = keras.layers.Activation('relu', name='ReLU_3b')(conv3d_3b)

    # Res3D Block 4
    conv3d_4a_1 = keras.layers.Conv1D(256, (1,1,1), strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_4a_1')(conv3d_3b)
    conv3d_4a_1 = keras.layers.BatchNormalization(name='BatchNorm_4a_1')(conv3d_4a_1)
    conv3d_4a_a = keras.layers.Conv1D(256, (3,3,3), strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_4a_a')(conv3d_3b)
    conv3d_4a_a = keras.layers.BatchNormalization(name='BatchNorm_4a_a')(conv3d_4a_a)
    conv3d_4a_a = keras.layers.Activation('relu', name='ReLU_4a_a')(conv3d_4a_a)
    conv3d_4a_b = keras.layers.Conv1D(256, (3,3,3), strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_4a_b')(conv3d_4a_a)
    conv3d_4a_b = keras.layers.BatchNormalization(name='BatchNorm_4a_b')(conv3d_4a_b)
    conv3d_4a = keras.layers.Add(name='Add_4a')([conv3d_4a_1, conv3d_4a_b])
    conv3d_4a = keras.layers.Activation('relu', name='ReLU_4a')(conv3d_4a)

    conv3d_4b_a = keras.layers.Conv1D(256, (3,3,3), strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_4b_a')(conv3d_4a)
    conv3d_4b_a = keras.layers.BatchNormalization(name='BatchNorm_4b_a')(conv3d_4b_a)
    conv3d_4b_a = keras.layers.Activation('relu', name='ReLU_4b_a')(conv3d_4b_a)
    conv3d_4b_b = keras.layers.Conv1D(256, (3,3,3), strides=(1,1,1), padding='same', 
                    dilation_rate=(1,1,1), kernel_initializer='he_normal',
                    kernel_regularizer=l2(weight_decay), use_bias=False, 
                    name='Conv1D_4b_b')(conv3d_4b_a)
    conv3d_4b_b = keras.layers.BatchNormalization(name='BatchNorm_4b_b')(conv3d_4b_b)
    conv3d_4b = keras.layers.Add(name='Add_4b')([conv3d_4a, conv3d_4b_b])
    conv3d_4b = keras.layers.Activation('relu', name='ReLU_4b')(conv3d_4b)

    return conv3d_4b

# %%
get_model5((224,3),2).summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_27 (InputLayer)        (None, 224, 3)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 222, 128)          1280
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 111, 128)          0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 109, 128)          49280
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 54, 128)           0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 52, 128)           49280
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 26, 128)           0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 24, 128)           49280
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 12, 128)           0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1536)              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 150)               230550
# _________________________________________________________________
# dense_28 (Dense)             (None, 100)               15100
# _________________________________________________________________
# dense_29 (Dense)             (None, 2)                 202
# =================================================================
# Total params: 394,972
# Trainable params: 394,972
# Non-trainable params: 0
# _________________________________________________________________

# %%
def cnn_model(input_shape, drop_rate=0.5, nb_classes=2):
    model=Sequential()
    
    # Layer 1
    model.add(Conv1D (kernel_size=3, filters=256, strides=1, padding='same',
                      kernel_initializer='he_uniform', input_shape=input_shape))                  
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    # Layer 2
    model.add(Conv1D(kernel_size=3, filters=256, strides=1, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    # Layer 3
    model.add(Conv1D (kernel_size=3, filters=256, strides=2, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
#     model.add(MaxPooling1D(pool_size=2, strides=2))
    
    # Layer 3
    model.add(Conv1D (kernel_size=3, filters=256, strides=2, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
#     model.add(MaxPooling1D(pool_size=2, strides=2))
    
    # Layer 3
    model.add(Conv1D (kernel_size=3, filters=256, strides=2, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
#     model.add(MaxPooling1D(pool_size=2, strides=2))
    
    # Layer 3
    model.add(Conv1D (kernel_size=3, filters=256, strides=2, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    

    

    # Layer 11
    model.add(Dropout(drop_rate))
    model.add(GlobalAveragePooling1D())

    # Layer 12
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    
    return model

# %%
from tensorflow.keras.layers import Conv2D,GlobalAveragePooling2D
def cnn_model(input_shape, drop_rate=0.5, nb_classes=2):
    model=Sequential()
    
    # Layer 1
    model.add(Conv2D (kernel_size=3, filters=256, strides=1, padding='same',
                      kernel_initializer='he_uniform', input_shape=input_shape))                  
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    # Layer 2
    model.add(Conv2D(kernel_size=3, filters=256, strides=1, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    # Layer 3
    model.add(Conv2D (kernel_size=3, filters=256, strides=2, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
#     model.add(MaxPooling2D(pool_size=2, strides=2))
    
    # Layer 3
    model.add(Conv2D (kernel_size=3, filters=256, strides=2, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
#     model.add(MaxPooling2D(pool_size=2, strides=2))
    
    # Layer 3
    model.add(Conv2D (kernel_size=3, filters=256, strides=2, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
#     model.add(MaxPooling2D(pool_size=2, strides=2))
    
    # Layer 3
    model.add(Conv2D (kernel_size=3, filters=256, strides=2, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    

    

    # Layer 11
    model.add(Dropout(drop_rate))
    model.add(GlobalAveragePooling2D())

    # Layer 12
    model.add(Dense(nb_classes))
    model.add(Activation('softmax'))
    
    return model

# %%
# # test result visulization
# def test(model,weight_path,X_test,y_test):
#     model = model
#     model.load_weights(weigth_file)
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#         print("Normalized confusion matrix")
    else:
#         print('Confusion matrix, without normalization')
        pass
#     print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
def one_shot(e_num = 3):
    batch_size = 16
    epochs = 100
    input_shape = (224,63)
    output_size = 2
    
    
    
    now = datetime.now()
    nowDate = now.strftime('%d_%H_%M_%S')
    model_name = 'my_model'+ nowDate
    
    
#     model = get_model5(input_shape = (224,63),nb_classes = 2)
    model = cnn_model(input_shape = (32,32,63),nb_classes = 2)
#     model = MyModel(training=True)
#     model = conv2d(input_shape = (16,16,63),nb_classes = 2)
    
#     model = cnn_model(input_shape=input_shape, output_size=output_size)
    model.summary()
    
    model = multi_gpu_model(model,gpus=2)
    model.summary()
    model.compile(loss=tf.keras.losses.binary_crossentropy, optimizer='sgd')
    
    # Validation 점수가 가장 좋은 모델만 저장합니다.
    checkpoint_path = os.path.join(model_path, model_name)
    os.makedirs(checkpoint_path, exist_ok=True)
    model_file_path = os.path.join(checkpoint_path, 'Epoch_{epoch:03d}_Val_{val_loss:.3f}.hdf5')
    checkpoint = ModelCheckpoint(filepath=model_file_path, monitor='val_loss', verbose=1, save_best_only=True)

    # 10회 간 Validation 점수가 좋아지지 않으면 중지합니다.
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=5, min_lr=0.001)
    
    train_list,val_list,test_list = subject_split(S_cnt = S_cnt,using_num=[0,1],print_list=True)
    X_train,y_train,X_val,y_val,X_test,y_test = preprocessing(train_list,val_list,test_list,is_scale=True,e_num=e_num)
    
    
    print('train len : ', np.shape(X_train),np.shape(y_train))
    print('val len : ', np.shape(X_val),np.shape(y_val))
    print('test len : ', np.shape(X_test),np.shape(y_test))
    history = model.fit(
    X_train, y_train, validation_data=(X_val,y_val),
    epochs=epochs, batch_size=batch_size,  shuffle=True,
    callbacks=[checkpoint, early_stopping])
#     X_train, X_train, validation_data=(X_val,X_val),
#     epochs=epochs, batch_size=batch_size,  shuffle=True,
#     callbacks=[checkpoint, early_stopping,reduce_lr])    
    
        
    plt.plot(history.epoch, history.history['loss'], '-o', label='training_loss')
    plt.plot(history.epoch, history.history['val_loss'], '-o', label='validation_loss')
    plt.legend()
    plt.xlim(left=0)
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.show()
        
    checkpoint_path = os.path.join(model_path, model_name)
    print(checkpoint_path)
    weigth_files = glob.glob('{}/*.hdf5'.format(checkpoint_path))
    weigth_files.sort()
    weigth_file = weigth_files[-1]
    print(weigth_files)
    print(weigth_file)
    model.load_weights(weigth_file)
    
    
    y_pred = model.predict(X_test)
#     print(y_pred)
#     print(y_test)
    y_true,y_pred = np.argmax(y_test,axis=-1),np.argmax(y_pred,axis=-1)
    test_acc = accuracy_score(y_true,y_pred)
    cnf_matrix = confusion_matrix(y_true, y_pred)
    plot_confusion_matrix(cnf_matrix,['N','MCI'],title='model : {} , test_acc : {}'.format(model_name,test_acc))

# %%
one_shot(e_num=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_213 (Conv2D)          (None, 32, 32, 256)       145408
# _________________________________________________________________
# batch_normalization_229 (Bat (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_169 (Activation)  (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_214 (Conv2D)          (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_230 (Bat (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_170 (Activation)  (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_215 (Conv2D)          (None, 16, 16, 256)       590080
# _________________________________________________________________
# batch_normalization_231 (Bat (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_171 (Activation)  (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_216 (Conv2D)          (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_232 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_172 (Activation)  (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_217 (Conv2D)          (None, 4, 4, 256)         590080
# _________________________________________________________________
# batch_normalization_233 (Bat (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_173 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_218 (Conv2D)          (None, 2, 2, 256)         590080
# _________________________________________________________________
# batch_normalization_234 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_174 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# global_average_pooling2d_19  (None, 256)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 2)                 514
# _________________________________________________________________
# activation_175 (Activation)  (None, 2)                 0
# =================================================================
# Total params: 3,102,466
# Trainable params: 3,099,394
# Non-trainable params: 3,072
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# conv2d_213_input (InputLayer)   (None, 32, 32, 63)   0
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 32, 32, 63)   0           conv2d_213_input[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 32, 32, 63)   0           conv2d_213_input[0][0]
# __________________________________________________________________________________________________
# sequential_9 (Sequential)       (None, 2)            3102466     lambda_38[0][0]
#                                                                  lambda_39[0][0]
# __________________________________________________________________________________________________
# activation_175 (Concatenate)    (None, 2)            0           sequential_9[1][0]
#                                                                  sequential_9[2][0]
# ==================================================================================================
# Total params: 3,102,466
# Trainable params: 3,099,394
# Non-trainable params: 3,072
# __________________________________________________________________________________________________
# label 0 split result = train : 66 , val : 8 , test : 21 :
# label 1 split result = train : 48 , val : 6 , test : 15 :
# total split result = train : 114 , val : 14 , test : 36
#
# train_list
#  ['S002', 'S005', 'S009', 'S010', 'S011', 'S017', 'S018', 'S020', 'S026', 'S028', 'S029', 'S030', 'S031', 'S032', 'S033', 'S034', 'S035', 'S036', 'S037', 'S038', 'S042', 'S043', 'S045', 'S046', 'S047', 'S049', 'S051', 'S057', 'S058', 'S059', 'S060', 'S061', 'S062', 'S063', 'S064', 'S065', 'S068', 'S069', 'S072', 'S073', 'S075', 'S076', 'S078', 'S080', 'S081', 'S083', 'S084', 'S085', 'S086', 'S087', 'S088', 'S089', 'S090', 'S091', 'S092', 'S093', 'S094', 'S095', 'S096', 'S097', 'S100', 'S102', 'S103', 'S105', 'S108', 'S109', 'S110', 'S112', 'S113', 'S115', 'S116', 'S117', 'S118', 'S120', 'S121', 'S122', 'S123', 'S124', 'S125', 'S127', 'S128', 'S129', 'S130', 'S131', 'S134', 'S136', 'S137', 'S138', 'S140', 'S141', 'S145', 'S146', 'S147', 'S148', 'S149', 'S150', 'S151', 'S152', 'S153', 'S154', 'S158', 'S159', 'S161', 'S162', 'S167', 'S168', 'S171', 'S173', 'S175', 'S176', 'S177', 'S178', 'S184', 'S190']
#
# val_list
#  ['S024', 'S039', 'S040', 'S055', 'S056', 'S114', 'S126', 'S143', 'S144', 'S155', 'S163', 'S170', 'S172', 'S174']
#
# test_list
#  ['S001', 'S003', 'S004', 'S007', 'S008', 'S019', 'S021', 'S023', 'S027', 'S041', 'S048', 'S050', 'S053', 'S054', 'S070', 'S077', 'S079', 'S082', 'S098', 'S099', 'S101', 'S104', 'S111', 'S119', 'S132', 'S133', 'S135', 'S139', 'S157', 'S160', 'S164', 'S165', 'S183', 'S187', 'S191', 'S192']
# train_list data load
# val_list data load
# ['S024', 'S039', 'S040', 'S055', 'S056', 'S114', 'S126', 'S143', 'S144', 'S155', 'S163', 'S170', 'S172', 'S174']
# test_list data load
# ['S001', 'S003', 'S004', 'S007', 'S008', 'S019', 'S021', 'S023', 'S027', 'S041', 'S048', 'S050', 'S053', 'S054', 'S070', 'S077', 'S079', 'S082', 'S098', 'S099', 'S101', 'S104', 'S111', 'S119', 'S132', 'S133', 'S135', 'S139', 'S157', 'S160', 'S164', 'S165', 'S183', 'S187', 'S191', 'S192']
# train len :  (323, 32, 32, 63) (323, 2)
# val len :  (37, 32, 32, 63) (37, 2)
# test len :  (96, 32, 32, 63) (96, 2)
# Train on 323 samples, validate on 37 samples
# Epoch 1/100
# 304/323 [===========================>..] - ETA: 1s - loss: 0.8217
# Epoch 00001: val_loss improved from inf to 0.71014, saving model to /home/ubuntu/Dataset/model/my_model09_16_27_50/Epoch_001_Val_0.710.hdf5
# 323/323 [==============================] - 32s 99ms/step - loss: 0.8180 - val_loss: 0.7101
# Epoch 2/100
# 288/323 [=========================>....] - ETA: 0s - loss: 0.4734
# Epoch 00002: val_loss did not improve from 0.71014
# 323/323 [==============================] - 1s 2ms/step - loss: 0.4702 - val_loss: 0.7193
# Epoch 3/100
# 304/323 [===========================>..] - ETA: 0s - loss: 0.3601
# Epoch 00003: val_loss did not improve from 0.71014
# 323/323 [==============================] - 1s 2ms/step - loss: 0.3672 - val_loss: 0.7846
# Epoch 4/100
# 304/323 [===========================>..] - ETA: 0s - loss: 0.2941
# Epoch 00004: val_loss did not improve from 0.71014
# 323/323 [==============================] - 1s 2ms/step - loss: 0.3002 - val_loss: 0.7778
# Epoch 5/100
# 320/323 [============================>.] - ETA: 0s - loss: 0.2103
# Epoch 00005: val_loss did not improve from 0.71014
# 323/323 [==============================] - 1s 2ms/step - loss: 0.2116 - val_loss: 0.8051
# Epoch 6/100
# 304/323 [===========================>..] - ETA: 0s - loss: 0.1467
# Epoch 00006: val_loss did not improve from 0.71014
# 323/323 [==============================] - 1s 2ms/step - loss: 0.1493 - val_loss: 0.8643
# Epoch 7/100
# 320/323 [============================>.] - ETA: 0s - loss: 0.1336
# Epoch 00007: val_loss did not improve from 0.71014
# 323/323 [==============================] - 1s 2ms/step - loss: 0.1339 - val_loss: 0.8550
# Epoch 8/100
# 304/323 [===========================>..] - ETA: 0s - loss: 0.0968
# Epoch 00008: val_loss did not improve from 0.71014
# 323/323 [==============================] - 1s 2ms/step - loss: 0.1089 - val_loss: 0.8605
# Epoch 9/100
# 288/323 [=========================>....] - ETA: 0s - loss: 0.0841
# Epoch 00009: val_loss did not improve from 0.71014
# 323/323 [==============================] - 1s 2ms/step - loss: 0.0885 - val_loss: 0.8770
# Epoch 10/100
# 304/323 [===========================>..] - ETA: 0s - loss: 0.0954
# Epoch 00010: val_loss did not improve from 0.71014
# 323/323 [==============================] - 1s 2ms/step - loss: 0.1062 - val_loss: 0.9638
# Epoch 11/100
# 288/323 [=========================>....] - ETA: 0s - loss: 0.0860
# Epoch 00011: val_loss did not improve from 0.71014
# 323/323 [==============================] - 1s 2ms/step - loss: 0.0869 - val_loss: 0.9325
# /home/ubuntu/Dataset/model/my_model09_16_27_50
# ['/home/ubuntu/Dataset/model/my_model09_16_27_50/Epoch_001_Val_0.710.hdf5']
# /home/ubuntu/Dataset/model/my_model09_16_27_50/Epoch_001_Val_0.710.hdf5

# %%
one_shot(e_num=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_219 (Conv2D)          (None, 32, 32, 256)       145408
# _________________________________________________________________
# batch_normalization_235 (Bat (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_176 (Activation)  (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_220 (Conv2D)          (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_236 (Bat (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_177 (Activation)  (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_221 (Conv2D)          (None, 16, 16, 256)       590080
# _________________________________________________________________
# batch_normalization_237 (Bat (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_178 (Activation)  (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_222 (Conv2D)          (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_238 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_179 (Activation)  (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_223 (Conv2D)          (None, 4, 4, 256)         590080
# _________________________________________________________________
# batch_normalization_239 (Bat (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_180 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_224 (Conv2D)          (None, 2, 2, 256)         590080
# _________________________________________________________________
# batch_normalization_240 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_181 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# global_average_pooling2d_20  (None, 256)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 2)                 514
# _________________________________________________________________
# activation_182 (Activation)  (None, 2)                 0
# =================================================================
# Total params: 3,102,466
# Trainable params: 3,099,394
# Non-trainable params: 3,072
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# conv2d_219_input (InputLayer)   (None, 32, 32, 63)   0
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 32, 32, 63)   0           conv2d_219_input[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 32, 32, 63)   0           conv2d_219_input[0][0]
# __________________________________________________________________________________________________
# sequential_10 (Sequential)      (None, 2)            3102466     lambda_40[0][0]
#                                                                  lambda_41[0][0]
# __________________________________________________________________________________________________
# activation_182 (Concatenate)    (None, 2)            0           sequential_10[1][0]
#                                                                  sequential_10[2][0]
# ==================================================================================================
# Total params: 3,102,466
# Trainable params: 3,099,394
# Non-trainable params: 3,072
# __________________________________________________________________________________________________
# label 0 split result = train : 66 , val : 8 , test : 21 :
# label 1 split result = train : 48 , val : 6 , test : 15 :
# total split result = train : 114 , val : 14 , test : 36
#
# train_list
#  ['S002', 'S005', 'S009', 'S010', 'S011', 'S017', 'S018', 'S020', 'S026', 'S028', 'S029', 'S030', 'S031', 'S032', 'S033', 'S034', 'S035', 'S036', 'S037', 'S038', 'S042', 'S043', 'S045', 'S046', 'S047', 'S049', 'S051', 'S057', 'S058', 'S059', 'S060', 'S061', 'S062', 'S063', 'S064', 'S065', 'S068', 'S069', 'S072', 'S073', 'S075', 'S076', 'S078', 'S080', 'S081', 'S083', 'S084', 'S085', 'S086', 'S087', 'S088', 'S089', 'S090', 'S091', 'S092', 'S093', 'S094', 'S095', 'S096', 'S097', 'S100', 'S102', 'S103', 'S105', 'S108', 'S109', 'S110', 'S112', 'S113', 'S115', 'S116', 'S117', 'S118', 'S120', 'S121', 'S122', 'S123', 'S124', 'S125', 'S127', 'S128', 'S129', 'S130', 'S131', 'S134', 'S136', 'S137', 'S138', 'S140', 'S141', 'S145', 'S146', 'S147', 'S148', 'S149', 'S150', 'S151', 'S152', 'S153', 'S154', 'S158', 'S159', 'S161', 'S162', 'S167', 'S168', 'S171', 'S173', 'S175', 'S176', 'S177', 'S178', 'S184', 'S190']
#
# val_list
#  ['S024', 'S039', 'S040', 'S055', 'S056', 'S114', 'S126', 'S143', 'S144', 'S155', 'S163', 'S170', 'S172', 'S174']
#
# test_list
#  ['S001', 'S003', 'S004', 'S007', 'S008', 'S019', 'S021', 'S023', 'S027', 'S041', 'S048', 'S050', 'S053', 'S054', 'S070', 'S077', 'S079', 'S082', 'S098', 'S099', 'S101', 'S104', 'S111', 'S119', 'S132', 'S133', 'S135', 'S139', 'S157', 'S160', 'S164', 'S165', 'S183', 'S187', 'S191', 'S192']
# train_list data load
# val_list data load
# ['S024', 'S039', 'S040', 'S055', 'S056', 'S114', 'S126', 'S143', 'S144', 'S155', 'S163', 'S170', 'S172', 'S174']
# test_list data load
# ['S001', 'S003', 'S004', 'S007', 'S008', 'S019', 'S021', 'S023', 'S027', 'S041', 'S048', 'S050', 'S053', 'S054', 'S070', 'S077', 'S079', 'S082', 'S098', 'S099', 'S101', 'S104', 'S111', 'S119', 'S132', 'S133', 'S135', 'S139', 'S157', 'S160', 'S164', 'S165', 'S183', 'S187', 'S191', 'S192']
# train len :  (322, 32, 32, 63) (322, 2)
# val len :  (49, 32, 32, 63) (49, 2)
# test len :  (97, 32, 32, 63) (97, 2)
# Train on 322 samples, validate on 49 samples
# Epoch 1/100
# 304/322 [===========================>..] - ETA: 1s - loss: 0.7847
# Epoch 00001: val_loss improved from inf to 0.71424, saving model to /home/ubuntu/Dataset/model/my_model09_16_29_58/Epoch_001_Val_0.714.hdf5
# 322/322 [==============================] - 33s 102ms/step - loss: 0.7808 - val_loss: 0.7142
# Epoch 2/100
# 304/322 [===========================>..] - ETA: 0s - loss: 0.4334
# Epoch 00002: val_loss improved from 0.71424 to 0.70764, saving model to /home/ubuntu/Dataset/model/my_model09_16_29_58/Epoch_002_Val_0.708.hdf5
# 322/322 [==============================] - 1s 2ms/step - loss: 0.4460 - val_loss: 0.7076
# Epoch 3/100
# 304/322 [===========================>..] - ETA: 0s - loss: 0.3120
# Epoch 00003: val_loss did not improve from 0.70764
# 322/322 [==============================] - 1s 2ms/step - loss: 0.3072 - val_loss: 0.7217
# Epoch 4/100
# 288/322 [=========================>....] - ETA: 0s - loss: 0.2266
# Epoch 00004: val_loss did not improve from 0.70764
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2482 - val_loss: 0.7473
# Epoch 5/100
# 320/322 [============================>.] - ETA: 0s - loss: 0.2131
# Epoch 00005: val_loss did not improve from 0.70764
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2156 - val_loss: 0.7688
# Epoch 6/100
# 288/322 [=========================>....] - ETA: 0s - loss: 0.1431
# Epoch 00006: val_loss did not improve from 0.70764
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1554 - val_loss: 0.8260
# Epoch 7/100
# 320/322 [============================>.] - ETA: 0s - loss: 0.1440
# Epoch 00007: val_loss did not improve from 0.70764
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1459 - val_loss: 0.8286
# Epoch 8/100
# 320/322 [============================>.] - ETA: 0s - loss: 0.0974
# Epoch 00008: val_loss did not improve from 0.70764
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1010 - val_loss: 0.8222
# Epoch 9/100
# 288/322 [=========================>....] - ETA: 0s - loss: 0.0857
# Epoch 00009: val_loss did not improve from 0.70764
# 322/322 [==============================] - 1s 2ms/step - loss: 0.0849 - val_loss: 0.8846
# Epoch 10/100
# 288/322 [=========================>....] - ETA: 0s - loss: 0.1416
# Epoch 00010: val_loss did not improve from 0.70764
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1414 - val_loss: 0.8865
# Epoch 11/100
# 304/322 [===========================>..] - ETA: 0s - loss: 0.0854
# Epoch 00011: val_loss did not improve from 0.70764
# 322/322 [==============================] - 1s 2ms/step - loss: 0.0847 - val_loss: 0.9214
# Epoch 12/100
# 304/322 [===========================>..] - ETA: 0s - loss: 0.0820
# Epoch 00012: val_loss did not improve from 0.70764
# 322/322 [==============================] - 1s 2ms/step - loss: 0.0940 - val_loss: 0.8831
# /home/ubuntu/Dataset/model/my_model09_16_29_58
# ['/home/ubuntu/Dataset/model/my_model09_16_29_58/Epoch_001_Val_0.714.hdf5', '/home/ubuntu/Dataset/model/my_model09_16_29_58/Epoch_002_Val_0.708.hdf5']
# /home/ubuntu/Dataset/model/my_model09_16_29_58/Epoch_002_Val_0.708.hdf5

# %%
one_shot(e_num=3)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_225 (Conv2D)          (None, 32, 32, 256)       145408
# _________________________________________________________________
# batch_normalization_241 (Bat (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_183 (Activation)  (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_226 (Conv2D)          (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_242 (Bat (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_184 (Activation)  (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_227 (Conv2D)          (None, 16, 16, 256)       590080
# _________________________________________________________________
# batch_normalization_243 (Bat (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_185 (Activation)  (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_228 (Conv2D)          (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_244 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_186 (Activation)  (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_229 (Conv2D)          (None, 4, 4, 256)         590080
# _________________________________________________________________
# batch_normalization_245 (Bat (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_187 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_230 (Conv2D)          (None, 2, 2, 256)         590080
# _________________________________________________________________
# batch_normalization_246 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_188 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# global_average_pooling2d_21  (None, 256)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 2)                 514
# _________________________________________________________________
# activation_189 (Activation)  (None, 2)                 0
# =================================================================
# Total params: 3,102,466
# Trainable params: 3,099,394
# Non-trainable params: 3,072
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# conv2d_225_input (InputLayer)   (None, 32, 32, 63)   0
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 32, 32, 63)   0           conv2d_225_input[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 32, 32, 63)   0           conv2d_225_input[0][0]
# __________________________________________________________________________________________________
# sequential_11 (Sequential)      (None, 2)            3102466     lambda_42[0][0]
#                                                                  lambda_43[0][0]
# __________________________________________________________________________________________________
# activation_189 (Concatenate)    (None, 2)            0           sequential_11[1][0]
#                                                                  sequential_11[2][0]
# ==================================================================================================
# Total params: 3,102,466
# Trainable params: 3,099,394
# Non-trainable params: 3,072
# __________________________________________________________________________________________________
# label 0 split result = train : 66 , val : 8 , test : 21 :
# label 1 split result = train : 48 , val : 6 , test : 15 :
# total split result = train : 114 , val : 14 , test : 36
#
# train_list
#  ['S002', 'S005', 'S009', 'S010', 'S011', 'S017', 'S018', 'S020', 'S026', 'S028', 'S029', 'S030', 'S031', 'S032', 'S033', 'S034', 'S035', 'S036', 'S037', 'S038', 'S042', 'S043', 'S045', 'S046', 'S047', 'S049', 'S051', 'S057', 'S058', 'S059', 'S060', 'S061', 'S062', 'S063', 'S064', 'S065', 'S068', 'S069', 'S072', 'S073', 'S075', 'S076', 'S078', 'S080', 'S081', 'S083', 'S084', 'S085', 'S086', 'S087', 'S088', 'S089', 'S090', 'S091', 'S092', 'S093', 'S094', 'S095', 'S096', 'S097', 'S100', 'S102', 'S103', 'S105', 'S108', 'S109', 'S110', 'S112', 'S113', 'S115', 'S116', 'S117', 'S118', 'S120', 'S121', 'S122', 'S123', 'S124', 'S125', 'S127', 'S128', 'S129', 'S130', 'S131', 'S134', 'S136', 'S137', 'S138', 'S140', 'S141', 'S145', 'S146', 'S147', 'S148', 'S149', 'S150', 'S151', 'S152', 'S153', 'S154', 'S158', 'S159', 'S161', 'S162', 'S167', 'S168', 'S171', 'S173', 'S175', 'S176', 'S177', 'S178', 'S184', 'S190']
#
# val_list
#  ['S024', 'S039', 'S040', 'S055', 'S056', 'S114', 'S126', 'S143', 'S144', 'S155', 'S163', 'S170', 'S172', 'S174']
#
# test_list
#  ['S001', 'S003', 'S004', 'S007', 'S008', 'S019', 'S021', 'S023', 'S027', 'S041', 'S048', 'S050', 'S053', 'S054', 'S070', 'S077', 'S079', 'S082', 'S098', 'S099', 'S101', 'S104', 'S111', 'S119', 'S132', 'S133', 'S135', 'S139', 'S157', 'S160', 'S164', 'S165', 'S183', 'S187', 'S191', 'S192']
# train_list data load
# val_list data load
# ['S024', 'S039', 'S040', 'S055', 'S056', 'S114', 'S126', 'S143', 'S144', 'S155', 'S163', 'S170', 'S172', 'S174']
# test_list data load
# ['S001', 'S003', 'S004', 'S007', 'S008', 'S019', 'S021', 'S023', 'S027', 'S041', 'S048', 'S050', 'S053', 'S054', 'S070', 'S077', 'S079', 'S082', 'S098', 'S099', 'S101', 'S104', 'S111', 'S119', 'S132', 'S133', 'S135', 'S139', 'S157', 'S160', 'S164', 'S165', 'S183', 'S187', 'S191', 'S192']
# train len :  (868, 32, 32, 63) (868, 2)
# val len :  (99, 32, 32, 63) (99, 2)
# test len :  (274, 32, 32, 63) (274, 2)
# Train on 868 samples, validate on 99 samples
# Epoch 1/100
# 864/868 [============================>.] - ETA: 0s - loss: 0.7327
# Epoch 00001: val_loss improved from inf to 0.69195, saving model to /home/ubuntu/Dataset/model/my_model09_16_31_31/Epoch_001_Val_0.692.hdf5
# 868/868 [==============================] - 35s 40ms/step - loss: 0.7322 - val_loss: 0.6920
# Epoch 2/100
# 848/868 [============================>.] - ETA: 0s - loss: 0.4748
# Epoch 00002: val_loss did not improve from 0.69195
# 868/868 [==============================] - 1s 2ms/step - loss: 0.4750 - val_loss: 0.7720
# Epoch 3/100
# 848/868 [============================>.] - ETA: 0s - loss: 0.3213
# Epoch 00003: val_loss did not improve from 0.69195
# 868/868 [==============================] - 1s 2ms/step - loss: 0.3209 - val_loss: 0.7234
# Epoch 4/100
# 864/868 [============================>.] - ETA: 0s - loss: 0.2171
# Epoch 00004: val_loss did not improve from 0.69195
# 868/868 [==============================] - 1s 2ms/step - loss: 0.2177 - val_loss: 0.7936
# Epoch 5/100
# 848/868 [============================>.] - ETA: 0s - loss: 0.1919
# Epoch 00005: val_loss did not improve from 0.69195
# 868/868 [==============================] - 1s 2ms/step - loss: 0.1930 - val_loss: 0.7730
# Epoch 6/100
# 848/868 [============================>.] - ETA: 0s - loss: 0.1399
# Epoch 00006: val_loss did not improve from 0.69195
# 868/868 [==============================] - 1s 2ms/step - loss: 0.1383 - val_loss: 0.7363
# Epoch 7/100
# 848/868 [============================>.] - ETA: 0s - loss: 0.1026
# Epoch 00007: val_loss did not improve from 0.69195
# 868/868 [==============================] - 1s 2ms/step - loss: 0.1036 - val_loss: 0.7727
# Epoch 8/100
# 848/868 [============================>.] - ETA: 0s - loss: 0.0841
# Epoch 00008: val_loss did not improve from 0.69195
# 868/868 [==============================] - 1s 2ms/step - loss: 0.0830 - val_loss: 0.7588
# Epoch 9/100
# 848/868 [============================>.] - ETA: 0s - loss: 0.0696
# Epoch 00009: val_loss did not improve from 0.69195
# 868/868 [==============================] - 1s 2ms/step - loss: 0.0696 - val_loss: 0.8189
# Epoch 10/100
# 832/868 [===========================>..] - ETA: 0s - loss: 0.0798
# Epoch 00010: val_loss did not improve from 0.69195
# 868/868 [==============================] - 1s 2ms/step - loss: 0.0776 - val_loss: 0.8750
# Epoch 11/100
# 864/868 [============================>.] - ETA: 0s - loss: 0.0563
# Epoch 00011: val_loss did not improve from 0.69195
# 868/868 [==============================] - 1s 2ms/step - loss: 0.0571 - val_loss: 0.9183
# /home/ubuntu/Dataset/model/my_model09_16_31_31
# ['/home/ubuntu/Dataset/model/my_model09_16_31_31/Epoch_001_Val_0.692.hdf5']
# /home/ubuntu/Dataset/model/my_model09_16_31_31/Epoch_001_Val_0.692.hdf5

# %%
one_shot(e_num=4)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_231 (Conv2D)          (None, 32, 32, 256)       145408
# _________________________________________________________________
# batch_normalization_247 (Bat (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_190 (Activation)  (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_232 (Conv2D)          (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_248 (Bat (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_191 (Activation)  (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_233 (Conv2D)          (None, 16, 16, 256)       590080
# _________________________________________________________________
# batch_normalization_249 (Bat (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_192 (Activation)  (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_234 (Conv2D)          (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_250 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_193 (Activation)  (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_235 (Conv2D)          (None, 4, 4, 256)         590080
# _________________________________________________________________
# batch_normalization_251 (Bat (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_194 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_236 (Conv2D)          (None, 2, 2, 256)         590080
# _________________________________________________________________
# batch_normalization_252 (Bat (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_195 (Activation)  (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# global_average_pooling2d_22  (None, 256)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 2)                 514
# _________________________________________________________________
# activation_196 (Activation)  (None, 2)                 0
# =================================================================
# Total params: 3,102,466
# Trainable params: 3,099,394
# Non-trainable params: 3,072
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# conv2d_231_input (InputLayer)   (None, 32, 32, 63)   0
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 32, 32, 63)   0           conv2d_231_input[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 32, 32, 63)   0           conv2d_231_input[0][0]
# __________________________________________________________________________________________________
# sequential_12 (Sequential)      (None, 2)            3102466     lambda_44[0][0]
#                                                                  lambda_45[0][0]
# __________________________________________________________________________________________________
# activation_196 (Concatenate)    (None, 2)            0           sequential_12[1][0]
#                                                                  sequential_12[2][0]
# ==================================================================================================
# Total params: 3,102,466
# Trainable params: 3,099,394
# Non-trainable params: 3,072
# __________________________________________________________________________________________________
# label 0 split result = train : 66 , val : 8 , test : 21 :
# label 1 split result = train : 48 , val : 6 , test : 15 :
# total split result = train : 114 , val : 14 , test : 36
#
# train_list
#  ['S002', 'S005', 'S009', 'S010', 'S011', 'S017', 'S018', 'S020', 'S026', 'S028', 'S029', 'S030', 'S031', 'S032', 'S033', 'S034', 'S035', 'S036', 'S037', 'S038', 'S042', 'S043', 'S045', 'S046', 'S047', 'S049', 'S051', 'S057', 'S058', 'S059', 'S060', 'S061', 'S062', 'S063', 'S064', 'S065', 'S068', 'S069', 'S072', 'S073', 'S075', 'S076', 'S078', 'S080', 'S081', 'S083', 'S084', 'S085', 'S086', 'S087', 'S088', 'S089', 'S090', 'S091', 'S092', 'S093', 'S094', 'S095', 'S096', 'S097', 'S100', 'S102', 'S103', 'S105', 'S108', 'S109', 'S110', 'S112', 'S113', 'S115', 'S116', 'S117', 'S118', 'S120', 'S121', 'S122', 'S123', 'S124', 'S125', 'S127', 'S128', 'S129', 'S130', 'S131', 'S134', 'S136', 'S137', 'S138', 'S140', 'S141', 'S145', 'S146', 'S147', 'S148', 'S149', 'S150', 'S151', 'S152', 'S153', 'S154', 'S158', 'S159', 'S161', 'S162', 'S167', 'S168', 'S171', 'S173', 'S175', 'S176', 'S177', 'S178', 'S184', 'S190']
#
# val_list
#  ['S024', 'S039', 'S040', 'S055', 'S056', 'S114', 'S126', 'S143', 'S144', 'S155', 'S163', 'S170', 'S172', 'S174']
#
# test_list
#  ['S001', 'S003', 'S004', 'S007', 'S008', 'S019', 'S021', 'S023', 'S027', 'S041', 'S048', 'S050', 'S053', 'S054', 'S070', 'S077', 'S079', 'S082', 'S098', 'S099', 'S101', 'S104', 'S111', 'S119', 'S132', 'S133', 'S135', 'S139', 'S157', 'S160', 'S164', 'S165', 'S183', 'S187', 'S191', 'S192']
# train_list data load
# val_list data load
# ['S024', 'S039', 'S040', 'S055', 'S056', 'S114', 'S126', 'S143', 'S144', 'S155', 'S163', 'S170', 'S172', 'S174']
# test_list data load
# ['S001', 'S003', 'S004', 'S007', 'S008', 'S019', 'S021', 'S023', 'S027', 'S041', 'S048', 'S050', 'S053', 'S054', 'S070', 'S077', 'S079', 'S082', 'S098', 'S099', 'S101', 'S104', 'S111', 'S119', 'S132', 'S133', 'S135', 'S139', 'S157', 'S160', 'S164', 'S165', 'S183', 'S187', 'S191', 'S192']
# train len :  (521, 32, 32, 63) (521, 2)
# val len :  (71, 32, 32, 63) (71, 2)
# test len :  (165, 32, 32, 63) (165, 2)
# Train on 521 samples, validate on 71 samples
# Epoch 1/100
# 496/521 [===========================>..] - ETA: 1s - loss: 0.7433
# Epoch 00001: val_loss improved from inf to 0.66639, saving model to /home/ubuntu/Dataset/model/my_model09_16_33_46/Epoch_001_Val_0.666.hdf5
# 521/521 [==============================] - 36s 69ms/step - loss: 0.7389 - val_loss: 0.6664
# Epoch 2/100
# 496/521 [===========================>..] - ETA: 0s - loss: 0.4132
# Epoch 00002: val_loss did not improve from 0.66639
# 521/521 [==============================] - 1s 2ms/step - loss: 0.4080 - val_loss: 0.7229
# Epoch 3/100
# 480/521 [==========================>...] - ETA: 0s - loss: 0.2778
# Epoch 00003: val_loss did not improve from 0.66639
# 521/521 [==============================] - 1s 2ms/step - loss: 0.2727 - val_loss: 0.7016
# Epoch 4/100
# 496/521 [===========================>..] - ETA: 0s - loss: 0.2144
# Epoch 00004: val_loss did not improve from 0.66639
# 521/521 [==============================] - 1s 2ms/step - loss: 0.2149 - val_loss: 0.7765
# Epoch 5/100
# 496/521 [===========================>..] - ETA: 0s - loss: 0.1953
# Epoch 00005: val_loss did not improve from 0.66639
# 521/521 [==============================] - 1s 2ms/step - loss: 0.1897 - val_loss: 0.8091
# Epoch 6/100
# 496/521 [===========================>..] - ETA: 0s - loss: 0.1098
# Epoch 00006: val_loss did not improve from 0.66639
# 521/521 [==============================] - 1s 2ms/step - loss: 0.1158 - val_loss: 0.8107
# Epoch 7/100
# 496/521 [===========================>..] - ETA: 0s - loss: 0.0918
# Epoch 00007: val_loss did not improve from 0.66639
# 521/521 [==============================] - 1s 2ms/step - loss: 0.0958 - val_loss: 0.8659
# Epoch 8/100
# 480/521 [==========================>...] - ETA: 0s - loss: 0.0744
# Epoch 00008: val_loss did not improve from 0.66639
# 521/521 [==============================] - 1s 2ms/step - loss: 0.0744 - val_loss: 0.8617
# Epoch 9/100
# 496/521 [===========================>..] - ETA: 0s - loss: 0.0826
# Epoch 00009: val_loss did not improve from 0.66639
# 521/521 [==============================] - 1s 2ms/step - loss: 0.0813 - val_loss: 0.8612
# Epoch 10/100
# 496/521 [===========================>..] - ETA: 0s - loss: 0.0750
# Epoch 00010: val_loss did not improve from 0.66639
# 521/521 [==============================] - 1s 2ms/step - loss: 0.0745 - val_loss: 0.8680
# Epoch 11/100
# 496/521 [===========================>..] - ETA: 0s - loss: 0.0638
# Epoch 00011: val_loss did not improve from 0.66639
# 521/521 [==============================] - 1s 2ms/step - loss: 0.0651 - val_loss: 0.9265
# /home/ubuntu/Dataset/model/my_model09_16_33_46
# ['/home/ubuntu/Dataset/model/my_model09_16_33_46/Epoch_001_Val_0.666.hdf5']
# /home/ubuntu/Dataset/model/my_model09_16_33_46/Epoch_001_Val_0.666.hdf5

# %%
X_train[:,:,[0,1]].shape
# Out:
# (869, 16, 2, 63)
